# %%
import numpy as np
from sklearn               import datasets
from sklearn.decomposition import PCA

import matplotlib        as mpl
import matplotlib.pyplot as plt
from   matplotlib        import cm
from   matplotlib.colors import ListedColormap
plt.style.use("seaborn-whitegrid")
SEED = 123

# %%
# %matplotlib inline

# %% [markdown]
# ## Colormap

# %%
cmap = cm.Set2
cmap.colors
# Out:
# ((0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254))

# %%
[mpl.colors.rgb2hex(rgb) for rgb in cmap.colors]
# Out:
# ['#66c2a5',
#  '#fc8d62',
#  '#8da0cb',
#  '#e78ac3',
#  '#a6d854',
#  '#ffd92f',
#  '#e5c494',
#  '#b3b3b3']

# %%
cols = [mpl.colors.rgb2hex(rgb) for rgb in cmap.colors]
coln = cmap.N

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(3,3))
for x, c in zip(range(coln), cols):
    ax.scatter(x, 0, s=100, color=c, label=c)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=15)
pass

# %% [markdown]
# # load data to plot

# %%
iris = datasets.load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
X = iris["data"]
c = iris["target"]

print(X.shape)
print(c.shape)
# Out:
# (150, 4)
# (150,)

# %%
pca   = PCA(n_components=2, random_state=SEED)
y_pca = pca.fit_transform(X)

##################################################
y = y_pca
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(4,4))
ax.scatter(y[:,0], y[:,1], c=c, cmap="Set2")
ax.set_title("PCA projection")
pass

# %% [markdown]
# ## Create your own colormap based on the color you want

# %%
newcolors = ['#66c2a5', '#fc8d62', '#e78ac3']
newcmp    = ListedColormap(newcolors)

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(3,3))

for x, c in enumerate(newcolors):
    ax.scatter(x, 0, s=100, color=c, label=c)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=15)
pass

# %%
X = iris["data"]
c = iris["target"]

##################################################
pca   = PCA(n_components=2, random_state=SEED)
y_pca = pca.fit_transform(X)

##################################################
y = y_pca
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(4,4))
ax.scatter(y[:,0], y[:,1], c=c, cmap=newcmp)
ax.set_title("PCA projection")
pass
